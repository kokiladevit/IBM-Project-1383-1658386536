# %%
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model
import numpy as nps

# %%
model=load_model(r'C:\Users\kowshik\project\flask\uploads\vegetable.h5')

# %%
img=image.load_img(r'C:\Users\kowshik\project\flask\sample_images\healthy_potato.jpg',grayscale=False,target_size=(128,128))

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1428EFBF160>

# %%
x=image.img_to_array(img)
x=nps.expand_dims(x,axis=0)

# %%
pred=(model.predict(x) > 0.5).astype("int32")
# Out:
# 1/1 [==============================] - 0s 78ms/step

# %%
pred
# Out:
# array([[0, 1, 0, 0, 0, 0, 0, 0, 0]])
